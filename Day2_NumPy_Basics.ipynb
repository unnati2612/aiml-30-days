# %% [markdown]
# <a href="https://colab.research.google.com/github/unnati2612/aiml-30-days/blob/main/Day2_NumPy_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
arr = np.array([10,20,30,40,50])
arr
# Out:
# array([10, 20, 30, 40, 50])

# %%
arr.shape
# Out:
# (5,)

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr.mean()
# Out:
# np.float64(30.0)

# %%
arr.max()
# Out:
# np.int64(50)

# %%
arr.min()
# Out:
# np.int64(10)

# %%
arr + 5
# Out:
# array([15, 25, 35, 45, 55])

# %%
arr*5
# Out:
# array([ 50, 100, 150, 200, 250])

# %%
matrix = np.array([
    [5,10,15,16],
    [25,30,35,36],
    [45,50,55,56]
])

matrix
# Out:
# array([[ 5, 10, 15, 16],
#        [25, 30, 35, 36],
#        [45, 50, 55, 56]])

# %%
matrix.shape
# Out:
# (3, 4)

# %%
matrix[0]
# Out:
# array([ 5, 10, 15, 16])

# %%
matrix[:,1]
# Out:
# array([10, 30, 50])

# %%
matrix[1,2]
# Out:
# np.int64(35)

# %% [markdown]
# # Day 2 – NumPy Basics
#
# ## What is NumPy?
# NumPy is a Python library used for numerical computations.
# It provides arrays which are faster and more efficient than Python lists.
#
# ## Key Learnings
# - Created 1D and 2D arrays
# - Understood shape and data types
# - Performed mathematical operations
# - Practiced indexing and slicing
#
# ## Why NumPy is important for ML?
# Machine Learning models work on numerical data.
# NumPy arrays are used internally by ML libraries like Scikit-learn and PyTorch.
